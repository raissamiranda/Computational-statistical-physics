# %% [markdown]
# <a href="https://colab.research.google.com/github/raissamiranda/Computational-statistical-physics/blob/main/Logistic_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1: Mapa Logístico

# %% [markdown]
# ## Discretized dynamics of a population

# %% [markdown]
# * Population tends to increase in the next generation
# * With an excess of individuals, resources become scarce and the population tends to decrease in the next generation
# * We will consider that the maximum population supported by the
# environment is 1
#
#
# $y_{n+1}$ $=$ $r$ $\times$ $y_{n}$ $\times$ $(1-y_{n})$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def equacao(y0, r):
  return r * y0 * (1 - y0)

# %%
def mapa_logistico(n, y0, r):
  yn = y0
  eixo_y = []
  eixo_y.append(y0)
    
  for i in range(1,n):
    yn = r * yn * (1 - yn)
    y_next = yn
    eixo_y.append(y_next)

  return eixo_y

# %%
def plota_mapa(eixo_y):
  plt.plot(eixo_y)

# %% [markdown]
# ## Graphs for y0 = 0.25 and varying the r value

# %%
f, axs = plt.subplots(2, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.25, 0.5)
axs[0, 0].plot(values1)
axs[0, 0].set_title('y0 = 0.25 and r = 0.5')
axs[0, 0].set_xlabel('n')
axs[0, 0].set_ylabel('population')

values2 = mapa_logistico(50, 0.25, 2.5)
axs[0, 1].plot(values2)
axs[0, 1].set_title('y0 = 0.25 and r = 2.5')
axs[0, 1].set_xlabel('n')
axs[0, 1].set_ylabel('population')

values3 = mapa_logistico(50, 0.25, 3.1)
axs[0, 2].plot(values3)
axs[0, 2].set_title('y0 = 0.25 and r = 3.1')
axs[0, 2].set_xlabel('n')
axs[0, 2].set_ylabel('population')

values4 = mapa_logistico(50, 0.25, 3.5)
axs[1, 0].plot(values4)
axs[1, 0].set_title('y0 = 0.25 and r = 3.5')
axs[1, 0].set_xlabel('n')
axs[1, 0].set_ylabel('population')

values4 = mapa_logistico(50, 0.25, 3.7)
axs[1, 1].plot(values4)
axs[1, 1].set_title('y0 = 0.25 and r = 3.7')
axs[1, 1].set_xlabel('n')
axs[1, 1].set_ylabel('population')

values5 = mapa_logistico(50, 0.5, 4.0)
axs[1, 2].plot(values5)
axs[1, 2].set_title('y0 = 0.25 and r = 4.0')
axs[1, 2].set_xlabel('n')
axs[1, 2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ## Graphs for y0 = 0.5 and varying the r value

# %%
f, axs = plt.subplots(2, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.5, 0.5)
axs[0, 0].plot(values1)
axs[0, 0].set_title('r = 0.5')
axs[0, 0].set_xlabel('n')
axs[0, 0].set_ylabel('population')

values2 = mapa_logistico(50, 0.5, 2.5)
axs[0, 1].plot(values2)
axs[0, 1].set_title('r = 2.5')
axs[0, 1].set_xlabel('n')
axs[0, 1].set_ylabel('population')

values3 = mapa_logistico(50, 0.5, 3.1)
axs[0, 2].plot(values3)
axs[0, 2].set_title('r = 3.1')
axs[0, 2].set_xlabel('n')
axs[0, 2].set_ylabel('population')

values4 = mapa_logistico(50, 0.5, 3.5)
axs[1, 0].plot(values4)
axs[1, 0].set_title('r = 3.5')
axs[1, 0].set_xlabel('n')
axs[1, 0].set_ylabel('population')

values4 = mapa_logistico(50, 0.5, 3.7)
axs[1, 1].plot(values4)
axs[1, 1].set_title('r = 3.7')
axs[1, 1].set_xlabel('n')
axs[1, 1].set_ylabel('population')

values5 = mapa_logistico(50, 0.5, 4.0)
axs[1, 2].plot(values5)
axs[1, 2].set_title('r = 4.0')
axs[1, 2].set_xlabel('n')
axs[1, 2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ## Graphs for y0 = 0.75 and varying the r value

# %%
f, axs = plt.subplots(2, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.75, 0.5)
axs[0, 0].plot(values1)
axs[0, 0].set_title('y0 = 0.75 and r = 0.5')
axs[0, 0].set_xlabel('n')
axs[0, 0].set_ylabel('population')

values2 = mapa_logistico(50, 0.75, 2.5)
axs[0, 1].plot(values2)
axs[0, 1].set_title('y0 = 0.75 and r = 2.5')
axs[0, 1].set_xlabel('n')
axs[0, 1].set_ylabel('population')

values3 = mapa_logistico(50, 0.75, 3.1)
axs[0, 2].plot(values3)
axs[0, 2].set_title('y0 = 0.75 and r = 3.1')
axs[0, 2].set_xlabel('n')
axs[0, 2].set_ylabel('population')

values4 = mapa_logistico(50, 0.75, 3.5)
axs[1, 0].plot(values4)
axs[1, 0].set_title('y0 = 0.75 and r = 3.5')
axs[1, 0].set_xlabel('n')
axs[1, 0].set_ylabel('population')

values4 = mapa_logistico(50, 0.75, 3.7)
axs[1, 1].plot(values4)
axs[1, 1].set_title('y0 = 0.75 and r = 3.7')
axs[1, 1].set_xlabel('n')
axs[1, 1].set_ylabel('population')

values5 = mapa_logistico(50, 0.75, 4.0)
axs[1, 2].plot(values5)
axs[1, 2].set_title('y0 = 0.75 and r = 4.0')
axs[1, 2].set_xlabel('n')
axs[1, 2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ### Conclusion

# %% [markdown]
# to do

# %% [markdown]
# ## Graphs for r = 0.5 and varying the y0 value slightly

# %%
f, axs = plt.subplots(1, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.5, 0.5)
axs[0].plot(values1)
axs[0].set_title('y0 = 0.5 and r = 0.5')
axs[0].set_xlabel('n')
axs[0].set_ylabel('population')

values2 = mapa_logistico(50, 0.501, 0.5)
axs[1].plot(values2)
axs[1].set_title('y0 = 0.501 and r = 0.5')
axs[1].set_xlabel('n')
axs[1].set_ylabel('population')

values3 = mapa_logistico(50, 0.5001, 0.5)
axs[2].plot(values3)
axs[2].set_title('y0 = 0.5001 and r = 0.5')
axs[2].set_xlabel('n')
axs[2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ## Graphs for r = 2.5 and varying the y0 value slightly

# %%
f, axs = plt.subplots(1, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.5, 2.5)
axs[0].plot(values1)
axs[0].set_title('y0 = 0.5 and r = 2.5')
axs[0].set_xlabel('n')
axs[0].set_ylabel('population')

values2 = mapa_logistico(50, 0.501, 2.5)
axs[1].plot(values2)
axs[1].set_title('y0 = 0.501 and r = 2.5')
axs[1].set_xlabel('n')
axs[1].set_ylabel('population')

values3 = mapa_logistico(50, 0.5001, 2.5)
axs[2].plot(values3)
axs[2].set_title('y0 = 0.5001 and r = 2.5')
axs[2].set_xlabel('n')
axs[2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ## Graphs for r = 3.1 and varying the y0 value slightly

# %%
f, axs = plt.subplots(1, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.5, 3.1)
axs[0].plot(values1)
axs[0].set_title('y0 = 0.5 and r = 3.1')
axs[0].set_xlabel('n')
axs[0].set_ylabel('population')

values2 = mapa_logistico(50, 0.501, 3.1)
axs[1].plot(values2)
axs[1].set_title('y0 = 0.501 and r = 3.1')
axs[1].set_xlabel('n')
axs[1].set_ylabel('population')

values3 = mapa_logistico(50, 0.5001, 3.1)
axs[2].plot(values3)
axs[2].set_title('y0 = 0.5001 and r = 3.1')
axs[2].set_xlabel('n')
axs[2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ## Graphs for r = 3.5 and varying the y0 value slightly

# %%
f, axs = plt.subplots(1, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.5, 3.5)
axs[0].plot(values1)
axs[0].set_title('y0 = 0.5 and r = 3.5')
axs[0].set_xlabel('n')
axs[0].set_ylabel('population')

values2 = mapa_logistico(50, 0.501, 3.5)
axs[1].plot(values2)
axs[1].set_title('y0 = 0.501 and r = 3.5')
axs[1].set_xlabel('n')
axs[1].set_ylabel('population')

values3 = mapa_logistico(50, 0.5001, 3.5)
axs[2].plot(values3)
axs[2].set_title('y0 = 0.5001 and r = 3.5')
axs[2].set_xlabel('n')
axs[2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ## Graphs for r = 3.7 and varying the y0 value slightly

# %%
f, axs = plt.subplots(1, 3, figsize=(15,8))

values1 = mapa_logistico(50, 0.5, 3.7)
axs[0].plot(values1)
axs[0].set_title('y0 = 0.5 and r = 3.7')
axs[0].set_xlabel('n')
axs[0].set_ylabel('population')

values2 = mapa_logistico(50, 0.501, 3.7)
axs[1].plot(values2)
axs[1].set_title('y0 = 0.501 and r = 3.7')
axs[1].set_xlabel('n')
axs[1].set_ylabel('population')

values3 = mapa_logistico(50, 0.5001, 3.7)
axs[2].plot(values3)
axs[2].set_title('y0 = 0.5001 and r = 3.7')
axs[2].set_xlabel('n')
axs[2].set_ylabel('population')
# Out:
# Text(0, 0.5, 'population')

# %% [markdown]
# ## Considering 10000 r values between $10^{-5}$ and $4$

# %% [markdown]
# You may have noticed that for certain values of r the system behavior, after a long time, cannot be predicted with security

# %%
r_values = np.linspace(10^-5, 4, num = 10000)

array = []
for i in r_values:
  y_values = mapa_logistico(1000, 0.5, i)
  array.append(y_values[900:-1])

plt.plot(r_values, array)
# Out:
# <ipython-input-4-f660ba091714>:7: RuntimeWarning: overflow encountered in double_scalars
#   yn = r * yn * (1 - yn)
# ...

# %% [markdown]
# ## Considering 10000 r values between  3.7  and  3.9

# %%
r_values = np.linspace(3.7, 3.9, num = 10000)

array = []
for i in r_values:
  y_values = mapa_logistico(1000, 0.5, i)
  array.append(y_values[900:-1])

plt.plot(r_values, array)

# %% [markdown]
# ## Considering 10000 r values between 3.840 and 3.856

# %%
r_values = np.linspace(3.840, 3.856, num = 10000)

array = []
for i in r_values:
  y_values = mapa_logistico(1000, 0.5, i)
  array.append(y_values[900:-1])

plt.plot(r_values, array)
